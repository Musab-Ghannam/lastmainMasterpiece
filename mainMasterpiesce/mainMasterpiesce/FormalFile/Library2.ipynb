-- %% [markdown]
-- # [LIBRARYBOOKS]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [LIBRARYBOOKS]    Script Date: 12/21/2022 2:10:45 AM ******/
CREATE DATABASE [LIBRARYBOOKS]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'LIBRARYBOOKS', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS01\MSSQL\DATA\LIBRARYBOOKS.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'LIBRARYBOOKS_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS01\MSSQL\DATA\LIBRARYBOOKS_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [LIBRARYBOOKS] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [LIBRARYBOOKS].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [LIBRARYBOOKS] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET ARITHABORT OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [LIBRARYBOOKS] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [LIBRARYBOOKS] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [LIBRARYBOOKS] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET  ENABLE_BROKER 
GO
ALTER DATABASE [LIBRARYBOOKS] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [LIBRARYBOOKS] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [LIBRARYBOOKS] SET  MULTI_USER 
GO
ALTER DATABASE [LIBRARYBOOKS] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [LIBRARYBOOKS] SET DB_CHAINING OFF 
GO
ALTER DATABASE [LIBRARYBOOKS] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [LIBRARYBOOKS] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [LIBRARYBOOKS] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [LIBRARYBOOKS] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [LIBRARYBOOKS] SET QUERY_STORE = ON
GO
ALTER DATABASE [LIBRARYBOOKS] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[cart]

-- %%
USE [LIBRARYBOOKS]
GO

-- %%
/****** Object:  Table [dbo].[cart]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cart](
	[cart_id] [int] IDENTITY(1,1) NOT NULL,
	[product_id] [int] NULL,
	[product_quantity] [int] NULL,
	[Userid] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[cart_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[category]

-- %%
/****** Object:  Table [dbo].[category]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[category](
	[category_id] [int] IDENTITY(1,1) NOT NULL,
	[category_name] [varchar](50) NULL,
	[category_PICTURE] [varchar](max) NULL,
	[DETAIL] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[category_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[City]

-- %%
/****** Object:  Table [dbo].[City]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[City](
	[city_Id] [int] IDENTITY(1,1) NOT NULL,
	[city_Name] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[city_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[comment]

-- %%
/****** Object:  Table [dbo].[comment]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[comment](
	[comment_id] [int] IDENTITY(1,1) NOT NULL,
	[product_id] [int] NULL,
	[customer_id] [int] NULL,
	[comment] [varchar](max) NULL,
	[comment_date] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[comment_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[contacus]

-- %%
/****** Object:  Table [dbo].[contacus]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[contacus](
	[contactus_id] [int] IDENTITY(1,1) NOT NULL,
	[fname] [varchar](50) NULL,
	[lname] [varchar](50) NULL,
	[sub] [varchar](50) NULL,
	[phone] [varchar](50) NULL,
	[detail] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[contactus_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[order_product]

-- %%
/****** Object:  Table [dbo].[order_product]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[order_product](
	[order_product_id] [int] IDENTITY(1,1) NOT NULL,
	[order_id] [int] NULL,
	[product_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[order_product_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[orders]

-- %%
/****** Object:  Table [dbo].[orders]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[orders](
	[order_id] [int] IDENTITY(1,1) NOT NULL,
	[order_date] [date] NULL,
	[customer_id] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[order_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[product]

-- %%
/****** Object:  Table [dbo].[product]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[product](
	[product_id] [int] IDENTITY(1,1) NOT NULL,
	[product_name] [varchar](50) NULL,
	[product_PICTURE] [varchar](max) NULL,
	[category_id] [int] NULL,
	[prodct_price] [float] NULL,
	[quantity] [int] NULL,
	[detalis] [varchar](max) NULL,
	[sale] [int] NULL,
	[newprice] [int] NULL,
	[author] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[product_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[role_Id] [int] IDENTITY(1,1) NOT NULL,
	[role_Name] [varchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[role_Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[users]

-- %%
/****** Object:  Table [dbo].[users]    Script Date: 12/21/2022 2:10:46 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[users](
	[Userid] [int] IDENTITY(1,1) NOT NULL,
	[EMAIL] [varchar](30) NOT NULL,
	[pass] [varchar](20) NULL,
	[First_name] [varchar](50) NOT NULL,
	[Last_Name] [varchar](50) NOT NULL,
	[PHONE] [varchar](15) NOT NULL,
	[city_Id] [int] NULL,
	[role_Id] [int] NULL,
	[user_PICTURE] [varchar](max) NULL,
	[contactus] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Userid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[EMAIL] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__cart__product_id__02FC7413]

-- %%
ALTER TABLE [dbo].[cart]  WITH CHECK ADD FOREIGN KEY([product_id])
REFERENCES [dbo].[product] ([product_id])
GO

-- %% [markdown]
-- # [FK__cart__Userid__03F0984C]

-- %%
ALTER TABLE [dbo].[cart]  WITH CHECK ADD FOREIGN KEY([Userid])
REFERENCES [dbo].[users] ([Userid])
GO

-- %% [markdown]
-- # [FK__comment__custome__07C12930]

-- %%
ALTER TABLE [dbo].[comment]  WITH CHECK ADD FOREIGN KEY([customer_id])
REFERENCES [dbo].[users] ([Userid])
GO

-- %% [markdown]
-- # [FK__comment__product__06CD04F7]

-- %%
ALTER TABLE [dbo].[comment]  WITH CHECK ADD FOREIGN KEY([product_id])
REFERENCES [dbo].[product] ([product_id])
GO

-- %% [markdown]
-- # [FK__order_pro__order__5FB337D6]

-- %%
ALTER TABLE [dbo].[order_product]  WITH CHECK ADD FOREIGN KEY([order_id])
REFERENCES [dbo].[orders] ([order_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__order_pro__produ__60A75C0F]

-- %%
ALTER TABLE [dbo].[order_product]  WITH CHECK ADD FOREIGN KEY([product_id])
REFERENCES [dbo].[product] ([product_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__orders__customer__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[orders]  WITH CHECK ADD FOREIGN KEY([customer_id])
REFERENCES [dbo].[users] ([Userid])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__product__categor__59FA5E80]

-- %%
ALTER TABLE [dbo].[product]  WITH CHECK ADD FOREIGN KEY([category_id])
REFERENCES [dbo].[category] ([category_id])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__users__city_Id__5441852A]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD FOREIGN KEY([city_Id])
REFERENCES [dbo].[City] ([city_Id])
GO

-- %% [markdown]
-- # [FK__users__role_Id__5535A963]

-- %%
ALTER TABLE [dbo].[users]  WITH CHECK ADD FOREIGN KEY([role_Id])
REFERENCES [dbo].[Roles] ([role_Id])
GO

-- %% [markdown]
-- # [LIBRARYBOOKS]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [LIBRARYBOOKS] SET  READ_WRITE 
GO
